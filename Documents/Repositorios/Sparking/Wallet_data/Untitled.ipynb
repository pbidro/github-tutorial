# %%
from cryptomarket.exchange.client import Client
api_key=''
api_secret=''
client = Client(api_key, api_secret)
client.get_ticker(market="EOSCLP")
client.get_balance()
# Out:
# <APIObject @ 0x7fbf51c448b0> {
#   "data": [
#     {
#       "ask": "4415",
#       "bid": "4372",
#       "high": "4579",
#       "last_price": "4371.5",
#       "low": "4100",
#       "market": "EOSCLP",
#       "timestamp": "2021-04-05T13:44:15.590831",
#       "volume": "34696.71465948891864523"
#     }
#   ]
# }

# %%
# Out:
# <APIObject @ 0x7fbf51c53db0> {
#   "data": [
#     {
#       "available": "0",
#       "balance": "0",
#       "currency_big_name": "",
#       "currency_decimal": 0,
#       "currency_postfix": "",
#       "currency_prefix": "",
#       "wallet": "PEN"
#     },
#     {
#       "available": "0",
#       "balance": "0",
#       "currency_big_name": "",
#       "currency_decimal": 0,
#       "currency_postfix": "",
#       "currency_prefix": "",
#       "wallet": "COP"
#     },
#     {
#       "available": "0",
#       "balance": "0",
#       "currency_big_name": "",
#       "currency_decimal": 0,
#       "currency_postfix": "",
#       "currency_prefix": "",
#       "wallet": "USD"
#     },
#     {
#       "available": "0.279329895470091201",
#       "balance": "0.279329895470091201",
#       "currency_big_name": "Peso Chileno",
#       "currency_decimal": 0,
#       "currency_postfix": "",
#       "currency_prefix": "$",
#       "wallet": "CLP"
#     },
#     {
# ...
